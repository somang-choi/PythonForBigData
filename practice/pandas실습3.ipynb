# %%
import numpy as np
import pandas as pd

# %%
df = pd.DataFrame(np.random.randn(5, 4))
df
# Out:
#           0         1         2         3
# 0  1.709570 -0.824415 -0.180977 -0.745022
# 1 -0.327722 -0.753564  0.204743 -0.180589
# 2 -1.271996 -1.593578 -0.765992 -1.727024
# 3 -0.441560  0.431191 -0.683698  1.193675
# 4  1.221146  0.046844  2.886805  0.350437

# %%
df.columns = ['A', 'B', 'C', 'D']

# %%
df
# Out:
#           A         B         C         D
# 0  1.709570 -0.824415 -0.180977 -0.745022
# 1 -0.327722 -0.753564  0.204743 -0.180589
# 2 -1.271996 -1.593578 -0.765992 -1.727024
# 3 -0.441560  0.431191 -0.683698  1.193675
# 4  1.221146  0.046844  2.886805  0.350437

# %%
df.index = pd.date_range('20180214', periods=5)

# %%
df
# Out:
#                    A         B         C         D
# 2018-02-14  1.709570 -0.824415 -0.180977 -0.745022
# 2018-02-15 -0.327722 -0.753564  0.204743 -0.180589
# 2018-02-16 -1.271996 -1.593578 -0.765992 -1.727024
# 2018-02-17 -0.441560  0.431191 -0.683698  1.193675
# 2018-02-18  1.221146  0.046844  2.886805  0.350437

# %%
type(df.index)
# Out:
# pandas.core.indexes.datetimes.DatetimeIndex

# %%
df['E'] = [9.9, np.nan, 10, 9.8, np.nan]

# %%
df
# Out:
#                    A         B         C         D     E
# 2018-02-14  1.709570 -0.824415 -0.180977 -0.745022   9.9
# 2018-02-15 -0.327722 -0.753564  0.204743 -0.180589   NaN
# 2018-02-16 -1.271996 -1.593578 -0.765992 -1.727024  10.0
# 2018-02-17 -0.441560  0.431191 -0.683698  1.193675   9.8
# 2018-02-18  1.221146  0.046844  2.886805  0.350437   NaN

# %%
df.dropna(how='all')

# %%
df.fillna(value=9.9999, inplace=True)

# %%
df
# Out:
#                    A         B         C         D        E
# 2018-02-14  1.709570 -0.824415 -0.180977 -0.745022   9.9000
# 2018-02-15 -0.327722 -0.753564  0.204743 -0.180589   9.9999
# 2018-02-16 -1.271996 -1.593578 -0.765992 -1.727024  10.0000
# 2018-02-17 -0.441560  0.431191 -0.683698  1.193675   9.8000
# 2018-02-18  1.221146  0.046844  2.886805  0.350437   9.9999

# %%
df.isnull
# Out:
# <bound method NDFrame.isnull of                    A         B         C         D        E
# 2018-02-14  1.709570 -0.824415 -0.180977 -0.745022   9.9000
# 2018-02-15 -0.327722 -0.753564  0.204743 -0.180589   9.9999
# 2018-02-16 -1.271996 -1.593578 -0.765992 -1.727024  10.0000
# 2018-02-17 -0.441560  0.431191 -0.683698  1.193675   9.8000
# 2018-02-18  1.221146  0.046844  2.886805  0.350437   9.9999>

# %%
a = pd.to_datetime('20180214')
df.drop(a)
# df.drop('20180214') 는 ERROR
# Out:
#                    A         B         C         D        E
# 2018-02-15 -0.327722 -0.753564  0.204743 -0.180589   9.9999
# 2018-02-16 -1.271996 -1.593578 -0.765992 -1.727024  10.0000
# 2018-02-17 -0.441560  0.431191 -0.683698  1.193675   9.8000
# 2018-02-18  1.221146  0.046844  2.886805  0.350437   9.9999

# %%
d1 = pd.to_datetime('20180214')
d2 = pd.to_datetime('20180218')

# %%
df.drop([d1, d2])
# Out:
#                    A         B         C         D        E
# 2018-02-15 -0.327722 -0.753564  0.204743 -0.180589   9.9999
# 2018-02-16 -1.271996 -1.593578 -0.765992 -1.727024  10.0000
# 2018-02-17 -0.441560  0.431191 -0.683698  1.193675   9.8000

# %%
df.drop('E', axis=1)
# Out:
#                    A         B         C         D
# 2018-02-14  1.709570 -0.824415 -0.180977 -0.745022
# 2018-02-15 -0.327722 -0.753564  0.204743 -0.180589
# 2018-02-16 -1.271996 -1.593578 -0.765992 -1.727024
# 2018-02-17 -0.441560  0.431191 -0.683698  1.193675
# 2018-02-18  1.221146  0.046844  2.886805  0.350437

# %%
df.drop(['B', 'D'], axis=1)
# Out:
#                    A         C        E
# 2018-02-14  1.709570 -0.180977   9.9000
# 2018-02-15 -0.327722  0.204743   9.9999
# 2018-02-16 -1.271996 -0.765992  10.0000
# 2018-02-17 -0.441560 -0.683698   9.8000
# 2018-02-18  1.221146  2.886805   9.9999

# %%
df.drop(df.index[1])
# Out:
#                    A         B         C         D        E
# 2018-02-14  1.709570 -0.824415 -0.180977 -0.745022   9.9000
# 2018-02-16 -1.271996 -1.593578 -0.765992 -1.727024  10.0000
# 2018-02-17 -0.441560  0.431191 -0.683698  1.193675   9.8000
# 2018-02-18  1.221146  0.046844  2.886805  0.350437   9.9999

# %%
df
# Out:
#                    A         B         C         D        E
# 2018-02-14  1.709570 -0.824415 -0.180977 -0.745022   9.9000
# 2018-02-15 -0.327722 -0.753564  0.204743 -0.180589   9.9999
# 2018-02-16 -1.271996 -1.593578 -0.765992 -1.727024  10.0000
# 2018-02-17 -0.441560  0.431191 -0.683698  1.193675   9.8000
# 2018-02-18  1.221146  0.046844  2.886805  0.350437   9.9999

# %%
df.drop(df.index[[1, 3]])
# Out:
#                    A         B         C         D        E
# 2018-02-14  1.709570 -0.824415 -0.180977 -0.745022   9.9000
# 2018-02-16 -1.271996 -1.593578 -0.765992 -1.727024  10.0000
# 2018-02-18  1.221146  0.046844  2.886805  0.350437   9.9999

# %%
df.drop(df.index[1:3])
# Out:
#                    A         B         C         D       E
# 2018-02-14  1.709570 -0.824415 -0.180977 -0.745022  9.9000
# 2018-02-17 -0.441560  0.431191 -0.683698  1.193675  9.8000
# 2018-02-18  1.221146  0.046844  2.886805  0.350437  9.9999

# %%
df.drop(df.columns[1], axis=1) # df.drop(df.columns[1])는 ERROR
# Out:
#                    A         C         D        E
# 2018-02-14  1.709570 -0.180977 -0.745022   9.9000
# 2018-02-15 -0.327722  0.204743 -0.180589   9.9999
# 2018-02-16 -1.271996 -0.765992 -1.727024  10.0000
# 2018-02-17 -0.441560 -0.683698  1.193675   9.8000
# 2018-02-18  1.221146  2.886805  0.350437   9.9999

# %%
df.drop(df.columns[1:3], axis=1)
# Out:
#                    A         D        E
# 2018-02-14  1.709570 -0.745022   9.9000
# 2018-02-15 -0.327722 -0.180589   9.9999
# 2018-02-16 -1.271996 -1.727024  10.0000
# 2018-02-17 -0.441560  1.193675   9.8000
# 2018-02-18  1.221146  0.350437   9.9999

# %%
df.drop(df.columns[[1, 4]], axis=1)
# Out:
#                    A         C         D
# 2018-02-14  1.709570 -0.180977 -0.745022
# 2018-02-15 -0.327722  0.204743 -0.180589
# 2018-02-16 -1.271996 -0.765992 -1.727024
# 2018-02-17 -0.441560 -0.683698  1.193675
# 2018-02-18  1.221146  2.886805  0.350437

# %%
df.drop(df.columns[[1, 4]], axis=1, inplace=True)

# %%
df
# Out:
#                    A         C         D
# 2018-02-14  1.709570 -0.180977 -0.745022
# 2018-02-15 -0.327722  0.204743 -0.180589
# 2018-02-16 -1.271996 -0.765992 -1.727024
# 2018-02-17 -0.441560 -0.683698  1.193675
# 2018-02-18  1.221146  2.886805  0.350437
