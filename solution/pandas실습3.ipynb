# %%
import numpy as np
import pandas as pd

# %%
df = pd.DataFrame(np.random.randn(5,4))

# %%
df
# Out:
#           0         1         2         3
# 0  0.695067  0.301264 -1.080417 -0.225526
# 1 -0.617717 -1.756238 -0.799530 -0.196359
# 2 -0.253480 -0.867610  0.439353 -0.511930
# 3 -0.983821 -0.803897  0.933554  0.514063
# 4  0.115299 -0.656048  0.552809 -1.131262

# %%
df.columns = ['A','B','C','D']
df
# Out:
#           A         B         C         D
# 0  0.695067  0.301264 -1.080417 -0.225526
# 1 -0.617717 -1.756238 -0.799530 -0.196359
# 2 -0.253480 -0.867610  0.439353 -0.511930
# 3 -0.983821 -0.803897  0.933554  0.514063
# 4  0.115299 -0.656048  0.552809 -1.131262

# %%
df.index = pd.date_range('20180214', periods=5)

# %%
df
# Out:
#                    A         B         C         D
# 2018-02-14  0.695067  0.301264 -1.080417 -0.225526
# 2018-02-15 -0.617717 -1.756238 -0.799530 -0.196359
# 2018-02-16 -0.253480 -0.867610  0.439353 -0.511930
# 2018-02-17 -0.983821 -0.803897  0.933554  0.514063
# 2018-02-18  0.115299 -0.656048  0.552809 -1.131262

# %%
type(df.index)
# Out:
# pandas.core.indexes.datetimes.DatetimeIndex

# %%
df['E'] = [9.9, np.nan, 10, 9.8, np.nan] 
df
# Out:
#                    A         B         C         D     E
# 2018-02-14  0.695067  0.301264 -1.080417 -0.225526   9.9
# 2018-02-15 -0.617717 -1.756238 -0.799530 -0.196359   NaN
# 2018-02-16 -0.253480 -0.867610  0.439353 -0.511930  10.0
# 2018-02-17 -0.983821 -0.803897  0.933554  0.514063   9.8
# 2018-02-18  0.115299 -0.656048  0.552809 -1.131262   NaN

# %%
#df.drop?
#df.dropna?

# %%
df.dropna(how='any')
# Out:
#                    A         B         C         D     E
# 2018-02-14  0.695067  0.301264 -1.080417 -0.225526   9.9
# 2018-02-16 -0.253480 -0.867610  0.439353 -0.511930  10.0
# 2018-02-17 -0.983821 -0.803897  0.933554  0.514063   9.8

# %%
df
# Out:
#                    A         B         C         D     E
# 2018-02-14  0.695067  0.301264 -1.080417 -0.225526   9.9
# 2018-02-15 -0.617717 -1.756238 -0.799530 -0.196359   NaN
# 2018-02-16 -0.253480 -0.867610  0.439353 -0.511930  10.0
# 2018-02-17 -0.983821 -0.803897  0.933554  0.514063   9.8
# 2018-02-18  0.115299 -0.656048  0.552809 -1.131262   NaN

# %%
df.dropna(how='all')
# Out:
#                    A         B         C         D     E
# 2018-02-14  0.695067  0.301264 -1.080417 -0.225526   9.9
# 2018-02-15 -0.617717 -1.756238 -0.799530 -0.196359   NaN
# 2018-02-16 -0.253480 -0.867610  0.439353 -0.511930  10.0
# 2018-02-17 -0.983821 -0.803897  0.933554  0.514063   9.8
# 2018-02-18  0.115299 -0.656048  0.552809 -1.131262   NaN

# %%
df.fillna(value=9.9)
# Out:
#                    A         B         C         D     E
# 2018-02-14  0.695067  0.301264 -1.080417 -0.225526   9.9
# 2018-02-15 -0.617717 -1.756238 -0.799530 -0.196359   9.9
# 2018-02-16 -0.253480 -0.867610  0.439353 -0.511930  10.0
# 2018-02-17 -0.983821 -0.803897  0.933554  0.514063   9.8
# 2018-02-18  0.115299 -0.656048  0.552809 -1.131262   9.9

# %%
df
# Out:
#                    A         B         C         D     E
# 2018-02-14  0.695067  0.301264 -1.080417 -0.225526   9.9
# 2018-02-15 -0.617717 -1.756238 -0.799530 -0.196359   NaN
# 2018-02-16 -0.253480 -0.867610  0.439353 -0.511930  10.0
# 2018-02-17 -0.983821 -0.803897  0.933554  0.514063   9.8
# 2018-02-18  0.115299 -0.656048  0.552809 -1.131262   NaN

# %%
df.fillna(value=9.9, inplace=True)

# %%
df
# Out:
#                    A         B         C         D     E
# 2018-02-14  0.695067  0.301264 -1.080417 -0.225526   9.9
# 2018-02-15 -0.617717 -1.756238 -0.799530 -0.196359   9.9
# 2018-02-16 -0.253480 -0.867610  0.439353 -0.511930  10.0
# 2018-02-17 -0.983821 -0.803897  0.933554  0.514063   9.8
# 2018-02-18  0.115299 -0.656048  0.552809 -1.131262   9.9

# %%
df.isnull()
# Out:
#                 A      B      C      D      E
# 2018-02-14  False  False  False  False  False
# 2018-02-15  False  False  False  False  False
# 2018-02-16  False  False  False  False  False
# 2018-02-17  False  False  False  False  False
# 2018-02-18  False  False  False  False  False

# %%
df
# Out:
#                    A         B         C         D     E
# 2018-02-14  0.695067  0.301264 -1.080417 -0.225526   9.9
# 2018-02-15 -0.617717 -1.756238 -0.799530 -0.196359   9.9
# 2018-02-16 -0.253480 -0.867610  0.439353 -0.511930  10.0
# 2018-02-17 -0.983821 -0.803897  0.933554  0.514063   9.8
# 2018-02-18  0.115299 -0.656048  0.552809 -1.131262   9.9

# %%
pd.to_datetime('20180214')
# Out:
# Timestamp('2018-02-14 00:00:00')

# %%
#df.drop('20180214')

# %%
#df.drop('2018-02-14')

# %%
df.drop(pd.to_datetime('20180214') )
# Out:
#                    A         B         C         D     E
# 2018-02-15 -0.617717 -1.756238 -0.799530 -0.196359   9.9
# 2018-02-16 -0.253480 -0.867610  0.439353 -0.511930  10.0
# 2018-02-17 -0.983821 -0.803897  0.933554  0.514063   9.8
# 2018-02-18  0.115299 -0.656048  0.552809 -1.131262   9.9

# %%
df
# Out:
#                    A         B         C         D     E
# 2018-02-14  0.695067  0.301264 -1.080417 -0.225526   9.9
# 2018-02-15 -0.617717 -1.756238 -0.799530 -0.196359   9.9
# 2018-02-16 -0.253480 -0.867610  0.439353 -0.511930  10.0
# 2018-02-17 -0.983821 -0.803897  0.933554  0.514063   9.8
# 2018-02-18  0.115299 -0.656048  0.552809 -1.131262   9.9

# %%
df.drop( [pd.to_datetime('20180214'), pd.to_datetime('20180215') ])
# Out:
#                    A         B         C         D     E
# 2018-02-16 -0.253480 -0.867610  0.439353 -0.511930  10.0
# 2018-02-17 -0.983821 -0.803897  0.933554  0.514063   9.8
# 2018-02-18  0.115299 -0.656048  0.552809 -1.131262   9.9

# %%
df.drop('E', axis=1)
# Out:
#                    A         B         C         D
# 2018-02-14  0.695067  0.301264 -1.080417 -0.225526
# 2018-02-15 -0.617717 -1.756238 -0.799530 -0.196359
# 2018-02-16 -0.253480 -0.867610  0.439353 -0.511930
# 2018-02-17 -0.983821 -0.803897  0.933554  0.514063
# 2018-02-18  0.115299 -0.656048  0.552809 -1.131262

# %%
df.drop(['B','D'], axis=1)
# Out:
#                    A         C     E
# 2018-02-14  0.695067 -1.080417   9.9
# 2018-02-15 -0.617717 -0.799530   9.9
# 2018-02-16 -0.253480  0.439353  10.0
# 2018-02-17 -0.983821  0.933554   9.8
# 2018-02-18  0.115299  0.552809   9.9

# %%
df.drop(df.index[1])
# Out:
#                    A         B         C         D     E
# 2018-02-14  0.695067  0.301264 -1.080417 -0.225526   9.9
# 2018-02-16 -0.253480 -0.867610  0.439353 -0.511930  10.0
# 2018-02-17 -0.983821 -0.803897  0.933554  0.514063   9.8
# 2018-02-18  0.115299 -0.656048  0.552809 -1.131262   9.9

# %%
df.drop(df.index[[1,3]])
# Out:
#                    A         B         C         D     E
# 2018-02-14  0.695067  0.301264 -1.080417 -0.225526   9.9
# 2018-02-16 -0.253480 -0.867610  0.439353 -0.511930  10.0
# 2018-02-18  0.115299 -0.656048  0.552809 -1.131262   9.9

# %%
df.drop(df.index[1:3])
# Out:
#                    A         B         C         D    E
# 2018-02-14  0.695067  0.301264 -1.080417 -0.225526  9.9
# 2018-02-17 -0.983821 -0.803897  0.933554  0.514063  9.8
# 2018-02-18  0.115299 -0.656048  0.552809 -1.131262  9.9

# %%
df.drop(df.columns[1] , axis=1)
# Out:
#                    A         C         D     E
# 2018-02-14  0.695067 -1.080417 -0.225526   9.9
# 2018-02-15 -0.617717 -0.799530 -0.196359   9.9
# 2018-02-16 -0.253480  0.439353 -0.511930  10.0
# 2018-02-17 -0.983821  0.933554  0.514063   9.8
# 2018-02-18  0.115299  0.552809 -1.131262   9.9

# %%
df.drop(df.columns[1:3], axis=1)
# Out:
#                    A         D     E
# 2018-02-14  0.695067 -0.225526   9.9
# 2018-02-15 -0.617717 -0.196359   9.9
# 2018-02-16 -0.253480 -0.511930  10.0
# 2018-02-17 -0.983821  0.514063   9.8
# 2018-02-18  0.115299 -1.131262   9.9

# %%
df.drop(df.columns[[1,3]], axis=1)
# Out:
#                    A         C     E
# 2018-02-14  0.695067 -1.080417   9.9
# 2018-02-15 -0.617717 -0.799530   9.9
# 2018-02-16 -0.253480  0.439353  10.0
# 2018-02-17 -0.983821  0.933554   9.8
# 2018-02-18  0.115299  0.552809   9.9

# %%
df
# Out:
#                    A         B         C         D     E
# 2018-02-14  0.695067  0.301264 -1.080417 -0.225526   9.9
# 2018-02-15 -0.617717 -1.756238 -0.799530 -0.196359   9.9
# 2018-02-16 -0.253480 -0.867610  0.439353 -0.511930  10.0
# 2018-02-17 -0.983821 -0.803897  0.933554  0.514063   9.8
# 2018-02-18  0.115299 -0.656048  0.552809 -1.131262   9.9

# %%
df.drop(df.columns[[1,3]], axis=1, inplace=True)

# %%
df
# Out:
#                    A         C     E
# 2018-02-14  0.695067 -1.080417   9.9
# 2018-02-15 -0.617717 -0.799530   9.9
# 2018-02-16 -0.253480  0.439353  10.0
# 2018-02-17 -0.983821  0.933554   9.8
# 2018-02-18  0.115299  0.552809   9.9
